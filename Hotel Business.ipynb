# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("C:\\Users\\TUSHAR GUPTA\\Desktop\\Python\\source-code\\3_project_hospitality_analysis\\datasets\\fact_bookings.csv")
df_date = pd.read_csv("C:\\Users\\TUSHAR GUPTA\\Desktop\\Python\\source-code\\3_project_hospitality_analysis\\datasets\\dim_date.csv")
df_hotel = pd.read_csv("C:\\Users\TUSHAR GUPTA\Desktop\\Python\\source-code\\3_project_hospitality_analysis\\datasets\\dim_hotels.csv")
df_rooms = pd.read_csv("C:\\Users\\TUSHAR GUPTA\Desktop\\Python\\source-code\\3_project_hospitality_analysis\\datasets\\dim_rooms.csv")
df_agg_bookings = pd.read_csv("C:\\Users\\TUSHAR GUPTA\\Desktop\\Python\\source-code\\3_project_hospitality_analysis\\datasets\\fact_aggregated_bookings.csv")

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_hotel.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotel.shape
# Out:
# (25, 4)

# %%
df_hotel.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotel.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotel.property_name.unique()
# Out:
# array(['Atliq Grands', 'Atliq Exotica', 'Atliq City', 'Atliq Blu',
#        'Atliq Bay', 'Atliq Palace', 'Atliq Seasons'], dtype=object)

# %%
df_hotel.city.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %%
df_agg_bookings.groupby('property_id')['successful_bookings'].sum().sort_values(ascending=False)
# Out:
# property_id
# 16559    7338
# 18562    7333
# 16563    7211
# 18560    6638
# 18561    6458
# 17563    6337
# 17559    6142
# 19560    6079
# 17560    6013
# 19562    5812
# 19561    5736
# 19563    5413
# 18559    5256
# 17561    5183
# 17558    5053
# 16562    4820
# 18563    4737
# 19559    4729
# 16560    4693
# 18558    4475
# 16561    4418
# 19558    4400
# 17564    3982
# 17562    3424
# 16558    3153
# Name: successful_bookings, dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings > df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.capacity.max()
# Out:
# 50.0

# %%
df_agg_bookings[df_agg_bookings.capacity==df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# # DATA CLEANING

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
# we have to clean the no_guest column as guest values can never in negatives

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
# Rid the records which are less than 0 in no_guests column

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
# As we can see value of revenue_generated columns seems to be outlier so below this we can check this whether it is outlier or not using 3 std deviation and if yes then we have to remove that records

# %%
avg,std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg,std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limit = avg + 3* std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit = avg-3*std
lower_limit
# Out:
# -263742.4278566132

# %%
# Any value below the lower_limit and value higher than higher_limit is outlier

# %%
df_bookings[df_bookings.revenue_generated<lower_limit]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
# so there in no records below lower limit

# %%
df_bookings[df_bookings.revenue_generated>=higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
# so we find the outlier now we have to remove this

# %%
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, we should not filter these values. Also we should not replace this rating with a median or mean rating etc

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agg_bookings.capacity.median()
# Out:
# 25.0

# %%
df_agg_bookings.capacity.fillna(df_agg_bookings.capacity.median(),inplace = True)
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings = df_agg_bookings[df_agg_bookings.successful_bookings <= df_agg_bookings.capacity]
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 4           16558      1-May-22           RT1                   18      19.0
# 5           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9194 rows x 5 columns]

# %%
df_agg_bookings.shape
# Out:
# (9194, 5)

# %% [markdown]
# # DATA TRANSFORMATION

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings.apply(lambda row: row['successful_bookings']/row['capacity'], axis=1)

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 4  0.947368
# 5  0.700000

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings['occ_pct'].apply(lambda x: round(x*100, 2))
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67

# %% [markdown]
# # INSIGHTS GENERATION

# %% [markdown]
# 1. What is an average occupancy rate in each of the room categories?

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 4    94.74
# 5    70.00

# %%
df_agg_bookings.groupby('room_category')['occ_pct'].mean()
# Out:
# room_category
# RT1    57.889643
# RT2    58.009756
# RT3    58.028213
# RT4    59.277925
# Name: occ_pct, dtype: float64

# %%
# which type of room is rt1 , rt2, rt3, rt4

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings,df_rooms,left_on='room_category',right_on='room_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3    94.74     RT1   Standard
# 4    70.00     RT1   Standard

# %%
df.groupby('room_class')['occ_pct'].mean()
# Out:
# room_class
# Elite           58.009756
# Premium         58.028213
# Presidential    59.277925
# Standard        57.889643
# Name: occ_pct, dtype: float64

# %%
df.groupby('room_class')['occ_pct'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='room_class'>

# %% [markdown]
# 3. Print average occupancy rate per city

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3    94.74     RT1   Standard
# 4    70.00     RT1   Standard

# %%
df_hotel.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df,df_hotel,on='property_id')
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      2-May-22           RT1                   20      30.0
# 2           16559      3-May-22           RT1                   17      30.0
# 3           16559      4-May-22           RT1                   21      30.0
# 4           16559      5-May-22           RT1                   16      30.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     27-Jul-22           RT4                   10      18.0
# 9190        16563     28-Jul-22           RT4                    9      18.0
# 9191        16563     29-Jul-22           RT4                    9      18.0
# 9192        16563     30-Jul-22           RT4                   11      18.0
# 9193        16563     31-Jul-22           RT4                   13      18.0
#
# ...

# %%
df.groupby('city')['occ_pct'].mean().round(2)
# Out:
# city
# Bangalore    56.33
# Delhi        61.51
# Hyderabad    58.12
# Mumbai       57.91
# Name: occ_pct, dtype: float64

# %% [markdown]
# 3. In the month of June, what is the occupancy for different cities

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
# 3        16559      4-May-22           RT1                   21      30.0
# 4        16559      5-May-22           RT1                   16      30.0
#
#    occ_pct room_id room_class  property_name category    city
# 0    83.33     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 1    66.67     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 2    56.67     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 3    70.00     RT1   Standard  Atliq Exotica   Luxury  Mumbai
# 4    53.33     RT1   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df = pd.merge(df,df_date,left_on='check_in_date',right_on='date')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_id    room_class  property_name category       city  \
# 0    60.00     RT1      Standard  Atliq Exotica   Luxury     Mumbai
# 1    60.98     RT2         Elite  Atliq Exotica   Luxury     Mumbai
# 2    62.50     RT3       Premium  Atliq Exotica   Luxury     Mumbai
# 3    72.22     RT4  Presidential  Atliq Exotica   Luxury     Mumbai
# 4    60.00     RT1      Standard      Atliq Bay   Luxury  Bangalore
#
#         date  mmm yy week no  day_type
# 0  10-May-22  May 22    W 20  weekeday
# ...

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_jun_22 = df[df['mmm yy']=='Jun 22']
df_jun_22
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
# 2203        16559     10-Jun-22           RT4                   11      18.0
# 2204        19562     10-Jun-22           RT1                   19      30.0
# ...           ...           ...           ...                  ...       ...
# 4294        17558     30-Jun-22           RT4                    3       6.0
# 4295        16563     30-Jun-22           RT1                   27      41.0
# 4296        16563     30-Jun-22           RT2                   22      38.0
# 4297        16563     30-Jun-22           RT3                   14      20.0
# 4298        16563     30-Jun-22           RT4                   12      18.0
#
# ...

# %%
df_jun_22.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending = False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: occ_pct, dtype: float64

# %%
df_jun_22.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# 4. When was the occupancy better? Weekday or Weekend?

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_id    room_class  property_name category       city  \
# 0    60.00     RT1      Standard  Atliq Exotica   Luxury     Mumbai
# 1    60.98     RT2         Elite  Atliq Exotica   Luxury     Mumbai
# 2    62.50     RT3       Premium  Atliq Exotica   Luxury     Mumbai
# 3    72.22     RT4  Presidential  Atliq Exotica   Luxury     Mumbai
# 4    60.00     RT1      Standard      Atliq Bay   Luxury  Bangalore
#
#         date  mmm yy week no  day_type
# 0  10-May-22  May 22    W 20  weekeday
# ...

# %%
df.groupby('day_type')['occ_pct'].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: occ_pct, dtype: float64

# %%
df.groupby('day_type')['occ_pct'].mean().round(2).plot(kind='pie')
# Out:
# <Axes: ylabel='occ_pct'>

# %% [markdown]
# 5. We got new data for the month of august. Append that to existing data

# %%
df_august = pd.read_csv("C:\\Users\\TUSHAR GUPTA\\Desktop\\Python\\source-code\\3_project_hospitality_analysis\\datasets\\new_data_august.csv")
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_id    room_class  property_name category       city  \
# 0    60.00     RT1      Standard  Atliq Exotica   Luxury     Mumbai
# 1    60.98     RT2         Elite  Atliq Exotica   Luxury     Mumbai
# 2    62.50     RT3       Premium  Atliq Exotica   Luxury     Mumbai
# 3    72.22     RT4  Presidential  Atliq Exotica   Luxury     Mumbai
# 4    60.00     RT1      Standard      Atliq Bay   Luxury  Bangalore
#
#         date  mmm yy week no  day_type
# 0  10-May-22  May 22    W 20  weekeday
# ...

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_id', 'room_class', 'property_name',
#        'category', 'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6497, 15)

# %%
latest_df = pd.concat([df,df_august], ignore_index=False)
latest_df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_id    room_class  property_name category       city  \
# 0    60.00     RT1      Standard  Atliq Exotica   Luxury     Mumbai
# 1    60.98     RT2         Elite  Atliq Exotica   Luxury     Mumbai
# 2    62.50     RT3       Premium  Atliq Exotica   Luxury     Mumbai
# 3    72.22     RT4  Presidential  Atliq Exotica   Luxury     Mumbai
# 4    60.00     RT1      Standard      Atliq Bay   Luxury  Bangalore
#
#         date  mmm yy week no  day_type  occ%
# 0  10-May-22  May 22    W 20  weekeday   NaN
# ...

# %%
latest_df.shape
# Out:
# (6504, 16)

# %% [markdown]
# 6. Print revenue realized per city

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotel.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_updated_bookings = pd.merge(df_bookings,df_hotel,on='property_id')
df_updated_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_updated_bookings.groupby('city')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# city
# Mumbai       668569251
# Bangalore    420383550
# Hyderabad    325179310
# Delhi        294404488
# Name: revenue_realized, dtype: int64

# %%
df_updated_bookings.groupby('city')['revenue_realized'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# 7. Print month by month revenue

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_updated_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_updated_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date['date']=pd.to_datetime(df_date['date'])

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-10  May 22    W 19   weekend
# 1 2022-05-10  May 22    W 19  weekeday
# 2 2022-05-10  May 22    W 19  weekeday
# 3 2022-05-10  May 22    W 19  weekeday
# 4 2022-05-10  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_updated_bookings['check_in_date'] = pd.to_datetime (df_updated_bookings['check_in_date'],format='mixed',dayfirst=True)
df_updated_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 4  May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_updated_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_updated_bookings=pd.merge(df_date,df_updated_bookings,left_on='date',right_on='check_in_date')
df_updated_bookings.head()
# Out:
#         date  mmm yy week no day_type        booking_id  property_id  \
# 0 2022-05-10  May 22    W 19  weekend  May102216558RT11        16558
# 1 2022-05-10  May 22    W 19  weekend  May102216558RT12        16558
# 2 2022-05-10  May 22    W 19  weekend  May102216558RT13        16558
# 3 2022-05-10  May 22    W 19  weekend  May102216558RT14        16558
# 4 2022-05-10  May 22    W 19  weekend  May102216558RT15        16558
#
#   booking_date check_in_date checkout_date  no_guests room_category  \
# 0     19-04-22    2022-05-10     12/5/2022        2.0           RT1
# 1     8/5/2022    2022-05-10      15-05-22        2.0           RT1
# 2     5/5/2022    2022-05-10     11/5/2022        2.0           RT1
# 3     5/5/2022    2022-05-10     11/5/2022        1.0           RT1
# 4     9/5/2022    2022-05-10      15-05-22        4.0           RT1
#
#   booking_platform  ratings_given booking_status  revenue_generated  \
# 0           others            5.0    Checked Out               9100
# ...

# %%
df_updated_bookings.groupby('mmm yy')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# mmm yy
# Jul 22    548606876
# May 22    548606876
# Jun 22    530909880
# Name: revenue_realized, dtype: int64

# %% [markdown]
# 8. Print revenue realized per hotel type

# %%
df_updated_bookings.groupby('property_name')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# property_name
# Atliq Exotica    306727356
# Atliq Palace     291245044
# Atliq City       268871380
# Atliq Bay        265252284
# Atliq Blu        254634012
# Atliq Grands     181085716
# Atliq Seasons     60307840
# Name: revenue_realized, dtype: int64

# %% [markdown]
# 9. Print average rating per city

# %%
df_updated_bookings.groupby('city')['ratings_given'].mean().sort_values(ascending=False)
# Out:
# city
# Mumbai       3.791667
# Hyderabad    3.709459
# Delhi        3.666667
# Bangalore    3.319149
# Name: ratings_given, dtype: float64

# %% [markdown]
# 10. Print a pie chart of revenue realized per booking platform

# %%
df_updated_bookings.groupby('booking_platform')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# booking_platform
# others            669538924
# makeyourtrip      328378084
# direct online     177791380
# logtrip           150826916
# tripster          118820668
# journey            92043424
# direct offline     90724236
# Name: revenue_realized, dtype: int64

# %%
df_updated_bookings.groupby('booking_platform')['revenue_realized'].sum().sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: ylabel='revenue_realized'>
